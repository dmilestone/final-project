# %%
import seaborn as sns
from scipy import stats
from scipy.stats import skew,norm
from scipy.stats.stats import pearsonr

# %%
df_1 = pd.read_csv('data/reviews_full.csv')
# checking shape ...
print("The dataset has {} rows and {} columns.".format(*df_1.shape))

# ... and duplicates
print("It contains {} duplicates.".format(df_1.duplicated().sum()))
# Out:
# The dataset has 170973 rows and 6 columns.
# It contains 0 duplicates.

# %%
df_1.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       38585  129120  2010-10-28        55877       Ritchie
# 1       38585  147273  2010-11-30       279973         Cathy
# 2       38585  198797  2011-03-14       411638           NaN
# 3       38585  201932  2011-03-17       441855          Bill
# 4       38585  341616  2011-06-28       657560        Joakim
#
#                                             comments
# 0  Evelyne is an accommodating host who lives in ...
# 1  Evelyne was very welcoming to her home; my fri...
# 2  I really enjoyed Evelyne's welcoming and bubbl...
# 3  Very gracious host and was helpful in all aspe...
# 4  Evelyn was very friendly and easy to comunicat...

# %%
df_2 = pd.read_csv('data/listings.csv')
df_2.head()
# Out:
#        id                                             name  host_id host_name  \
# 0   38585  Charming Victorian home - twin beds + breakfast   165529   Evelyne
# 1   80905                                 French Chic Loft   427027   Celeste
# 2  108061                  Walk downtown or UNCA, Pets OK!   320564      Lisa
# 3  155305               Cottage! BonPaul + Sharky's Hostel   746673   BonPaul
# 4  156805                Private Room "Ader" at BPS Hostel   746673   BonPaul
#
#    neighbourhood_group  neighbourhood  latitude  longitude        room_type  \
# 0                  NaN          28804  35.65146  -82.62792     Private room
# 1                  NaN          28801  35.59740  -82.55498  Entire home/apt
# 2                  NaN          28801  35.60670  -82.55563  Entire home/apt
# 3                  NaN          28806  35.57972  -82.59617  Entire home/apt
# 4                  NaN          28806  35.57755  -82.59697     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0     55               2                137  2019-11-11               1.24
# 1    765               1                102  2019-11-10               1.02
# 2     75              30                 88  2019-10-09               0.88
# 3    107               1                227  2019-11-18               2.24
# 4     71               1                 64  2019-11-02               0.64
#
#    calculated_host_listings_count  availability_365
# 0                               1                64
# 1                              10               347
# 2                               2               210
# 3                               7               347
# 4                               7               345

# %%
# merging full df_1 + add only specific columns from df_2
df = pd.merge(df_1, df_2[['host_id', 'latitude',
                          'longitude', 'number_of_reviews', 'id', 'room_type']], 
              left_on='listing_id', right_on='id', how='left')

df.head(3)
# Out:
#    listing_id    id_x        date  reviewer_id reviewer_name  \
# 0       38585  129120  2010-10-28        55877       Ritchie
# 1       38585  147273  2010-11-30       279973         Cathy
# 2       38585  198797  2011-03-14       411638           NaN
#
#                                             comments  host_id  latitude  \
# 0  Evelyne is an accommodating host who lives in ...   165529  35.65146
# 1  Evelyne was very welcoming to her home; my fri...   165529  35.65146
# 2  I really enjoyed Evelyne's welcoming and bubbl...   165529  35.65146
#
#    longitude  number_of_reviews   id_y     room_type
# 0  -82.62792                137  38585  Private room
# 1  -82.62792                137  38585  Private room
# 2  -82.62792                137  38585  Private room

# %%
# checking shape
print("The dataset has {} rows and {} columns.".format(*df.shape))
# Out:
# The dataset has 170973 rows and 12 columns.

# %%
# group by hosts and count the number of unique listings --> cast it to a dataframe
properties_per_host = pd.DataFrame(df.groupby('host_id')['listing_id'].nunique())

# sort unique values descending and show the Top20
properties_per_host.sort_values(by=['listing_id'], ascending=False, inplace=True)
properties_per_host.head(20)
# Out:
#            listing_id
# host_id
# 167186184          48
# 149601167          24
# 96187307           22
# 151397468          17
# 134903005          14
# 250328755          13
# 3665372            13
# 46001530           11
# 427027             10
# 151279507          10
# 96305927           10
# 53185861            9
# 1994122             8
# 175871539           8
# 746673              7
# 722034              7
# 33151095            7
# 7625694             7
# 181480147           5
# 60348510            5

# %%
# import necessary libraries
from nltk.corpus import stopwords


from collections import Counter
from PIL import Image

import re
import string
# load the SentimentIntensityAnalyser object in
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# assign it to another name to make it easier to use
analyzer = SentimentIntensityAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-20-bcc9f1f5d3b6> in <module>
#       1 # assign it to another name to make it easier to use
# ----> 2 analyzer = SentimentIntensityAnalyzer()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\nltk\sentiment\vader.py in __init__(self, lexicon_file)
#     332         self, lexicon_file="sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt"
#     333     ):
# --> 334         self.lexicon_file = nltk.data.load(lexicon_file)
#     335         self.lexicon = self.make_lex_dict()
#     336
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\nltk\data.py in _open(resource_url)
#     991
#     992     if protocol is None or protocol.lower() == 'nltk':
# --> 993         return find(path_, path + ['']).open()
#     994     elif protocol.lower() == 'file':
#     995         # urllib might not use mode='rb', so handle this one ourselves:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource vader_lexicon not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('vader_lexicon')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt
#
#   Searched in:
#     - 'C:\\Users\\nickb/nltk_data'
#     - 'C:\\Users\\nickb\\Anaconda3\\envs\\PythonData\\nltk_data'
#     - 'C:\\Users\\nickb\\Anaconda3\\envs\\PythonData\\share\\nltk_data'
#     - 'C:\\Users\\nickb\\Anaconda3\\envs\\PythonData\\lib\\nltk_data'
#     - 'C:\\Users\\nickb\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %%
# !pip install vader_lexicon
# Out:
# Collecting vader_lexicon
#   ERROR: Could not find a version that satisfies the requirement vader_lexicon (from versions: none)
# ERROR: No matching distribution found for vader_lexicon
