# %%
import pandas as pd
# %matplotlib notebook
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt

filename = "data/listings.csv"
listings_df = pd.read_csv(filename)
listings_df.head()
# Out:
#        id                                             name  host_id host_name  \
# 0   38585  Charming Victorian home - twin beds + breakfast   165529   Evelyne
# 1   80905                                 French Chic Loft   427027   Celeste
# 2  108061                  Walk downtown or UNCA, Pets OK!   320564      Lisa
# 3  155305               Cottage! BonPaul + Sharky's Hostel   746673   BonPaul
# 4  156805                Private Room "Ader" at BPS Hostel   746673   BonPaul
#
#    neighbourhood_group  neighbourhood  latitude  longitude        room_type  \
# 0                  NaN          28804  35.65146  -82.62792     Private room
# 1                  NaN          28801  35.59740  -82.55498  Entire home/apt
# 2                  NaN          28801  35.60670  -82.55563  Entire home/apt
# 3                  NaN          28806  35.57972  -82.59617  Entire home/apt
# 4                  NaN          28806  35.57755  -82.59697     Private room
#
# ...

# %%
#df['percent'] = df['rent']/df['total']
listings_df['occupancy'] = (365-listings_df['availability_365'])/365
listings_df.head()
# Out:
#        id                                             name  host_id host_name  \
# 0   38585  Charming Victorian home - twin beds + breakfast   165529   Evelyne
# 1   80905                                 French Chic Loft   427027   Celeste
# 2  108061                  Walk downtown or UNCA, Pets OK!   320564      Lisa
# 3  155305               Cottage! BonPaul + Sharky's Hostel   746673   BonPaul
# 4  156805                Private Room "Ader" at BPS Hostel   746673   BonPaul
#
#    neighbourhood_group  neighbourhood  latitude  longitude        room_type  \
# 0                  NaN          28804  35.65146  -82.62792     Private room
# 1                  NaN          28801  35.59740  -82.55498  Entire home/apt
# 2                  NaN          28801  35.60670  -82.55563  Entire home/apt
# 3                  NaN          28806  35.57972  -82.59617  Entire home/apt
# 4                  NaN          28806  35.57755  -82.59697     Private room
#
# ...

# %%
x_axis = range(365)
y_axis = listings_df["price"]

plt.title('Average Price of Listings Over 1 Year')
plt.plot(x_axis, y_axis,linewidth=2, markersize=12)
plt.xlabel('Timepoint (Days)')
plt.ylabel('Average Daily Rental Price ($)')

plt.savefig('linechart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-145333673238> in <module>
#       3
#       4 plt.title('Average Price of Listings Over 1 Year')
# ----> 5 plt.plot(x_axis, y_axis,linewidth=2, markersize=12)
#       6 plt.xlabel('Timepoint (Days)')
#       7 plt.ylabel('Average Daily Rental Price ($)')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...

# %%
occupancy= listings_df['occupancy']
listing_id= listings_df['id']

plt.bar(occupancy, listing_id)
plt.xlabel('Genre', fontsize=5)
plt.ylabel('No of Movies', fontsize=5)
plt.xticks(occupancy, listing_id, fontsize=5, rotation=30)
plt.title('Market Share for Each Genre 1995-2017')
plt.show()

# %%
#occupancy by listing
datapts2 = listings_df['occupancy']
forpanbar = pd.DataFrame(datapts2)
#newtry = forpanbar.reset_index()
#newtry

also = forpanbar.plot.bar(legend=False,rot=50)
also
plt.ylabel("Number of Data Points")
plt.title("Data Points Per Drug Treatment Regimen")
plt.savefig('barplot1')

# %%
x_axis = range(365)
y_axis = dateprice["price"]

plt.title('Average Price of Listings Over 1 Year')
plt.plot(x_axis, y_axis,linewidth=2, markersize=12)
plt.xlabel('Timepoint (Days)')
plt.ylabel('Average Daily Rental Price ($)')

plt.savefig('linechart')
plt.show()

# %%
filename_reviews = "data/reviews_full.csv"
reviews_data = pd.read_csv(filename_reviews)
reviews_data.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       38585  129120  2010-10-28        55877       Ritchie
# 1       38585  147273  2010-11-30       279973         Cathy
# 2       38585  198797  2011-03-14       411638           NaN
# 3       38585  201932  2011-03-17       441855          Bill
# 4       38585  341616  2011-06-28       657560        Joakim
#
#                                             comments
# 0  Evelyne is an accommodating host who lives in ...
# 1  Evelyne was very welcoming to her home; my fri...
# 2  I really enjoyed Evelyne's welcoming and bubbl...
# 3  Very gracious host and was helpful in all aspe...
# 4  Evelyn was very friendly and easy to comunicat...

# %%
filename_calendar = "data/calendar.csv"
calendar_data = pd.read_csv(filename_calendar)
calendar_data.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0     2283071  2019-11-28         f  $38.00         $38.00               1
# 1     2283071  2019-11-29         f  $38.00         $38.00               1
# 2     2283071  2019-11-30         f  $38.00         $38.00               1
# 3     2283071  2019-12-01         f  $38.00         $38.00               1
# 4     2283071  2019-12-02         f  $38.00         $38.00               1
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
calendar_data['price'] = calendar_data['price'].replace('[\$,]', '', regex=True).astype(float)
calendar_data.head()
# Out:
#    listing_id        date available  price adjusted_price  minimum_nights  \
# 0     2283071  2019-11-28         f   38.0         $38.00               1
# 1     2283071  2019-11-29         f   38.0         $38.00               1
# 2     2283071  2019-11-30         f   38.0         $38.00               1
# 3     2283071  2019-12-01         f   38.0         $38.00               1
# 4     2283071  2019-12-02         f   38.0         $38.00               1
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
day_totals = calendar_data.groupby('listing_id').count()
day_totals.head()
# Out:
#             date  available  price  adjusted_price  minimum_nights  \
# listing_id
# 38585        365        365    365             365             365
# 80905        365        365    365             365             365
# 108061       365        365    365             365             365
# 155305       365        365    365             365             365
# 156805       365        365    365             365             365
#
#             maximum_nights
# listing_id
# 38585                  365
# 80905                  365
# 108061                 365
# 155305                 365
# 156805                 365

# %%
booked_out = calendar_data.loc[calendar_data["available"]=="f",:]
booked_out.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0     2283071  2019-11-28         f  $38.00         $38.00               1
# 1     2283071  2019-11-29         f  $38.00         $38.00               1
# 2     2283071  2019-11-30         f  $38.00         $38.00               1
# 3     2283071  2019-12-01         f  $38.00         $38.00               1
# 4     2283071  2019-12-02         f  $38.00         $38.00               1
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
available_false = calendar_data.loc[calendar_data["available"]=="f",:]
booked_dates = available_false.groupby('listing_id').count()['available']
booked_dates = pd.DataFrame(booked_dates)
booked_dates
# Out:
#             available
# listing_id
# 38585             301
# 80905              18
# 108061            155
# 155305             18
# 156805             20
# ...               ...
# 40323675           18
# 40370417           10
# 40371638           36
# 40372482           22
# 40372837           29
#
# [2431 rows x 1 columns]

# %%
available_true = calendar_data.loc[calendar_data["available"]=="t",:]
nonbooked_dates = available_true.groupby('listing_id').count()['available']
nonbooked_dates = pd.DataFrame(nonbooked_dates)
nonbooked_dates
# Out:
#             available
# listing_id
# 38585              64
# 80905             347
# 108061            210
# 155305            347
# 156805            345
# ...               ...
# 40323675          347
# 40370417          355
# 40371638          329
# 40372482          343
# 40372837          336
#
# [2221 rows x 1 columns]

# %%
calendar_data['price'] = calendar_data['price'].replace('[\$,]', '', regex=True).astype(float)
calendar_data.head()
# Out:
#    listing_id        date available  price adjusted_price  minimum_nights  \
# 0     2283071  2019-11-28         f   38.0         $38.00               1
# 1     2283071  2019-11-29         f   38.0         $38.00               1
# 2     2283071  2019-11-30         f   38.0         $38.00               1
# 3     2283071  2019-12-01         f   38.0         $38.00               1
# 4     2283071  2019-12-02         f   38.0         $38.00               1
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
booked_dates = calendar_data.groupby('date').mean()['price']
booked_dates = pd.DataFrame(booked_dates)
booked_dates
# Out:
#                  price
# date
# 2019-11-28  158.063908
# 2019-11-29  172.692339
# 2019-11-30  166.969685
# 2019-12-01  142.653830
# 2019-12-02  136.508808
# ...                ...
# 2020-11-22  156.792298
# 2020-11-23  162.271610
# 2020-11-24  160.482589
# 2020-11-25  163.514543
# 2020-11-26  165.907415
#
# [365 rows x 1 columns]

# %%
booked_dates.reset_index()
# Out:
#            date       price
# 0    2019-11-28  158.063908
# 1    2019-11-29  172.692339
# 2    2019-11-30  166.969685
# 3    2019-12-01  142.653830
# 4    2019-12-02  136.508808
# ..          ...         ...
# 360  2020-11-22  156.792298
# 361  2020-11-23  162.271610
# 362  2020-11-24  160.482589
# 363  2020-11-25  163.514543
# 364  2020-11-26  165.907415
#
# [365 rows x 2 columns]

# %%
calendar_data['price'] = calendar_data['price'].replace('[\$,]', '', regex=True).astype(float)
calendar_data.head()
# Out:
#    listing_id        date available  price adjusted_price  minimum_nights  \
# 0     2283071  2019-11-28         f   38.0         $38.00               1
# 1     2283071  2019-11-29         f   38.0         $38.00               1
# 2     2283071  2019-11-30         f   38.0         $38.00               1
# 3     2283071  2019-12-01         f   38.0         $38.00               1
# 4     2283071  2019-12-02         f   38.0         $38.00               1
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
dateprice = calendar_data.groupby('date').mean()['price']
dateprice = pd.DataFrame(dateprice)
dateprice.head()
# Out:
#                  price
# date
# 2019-11-28  158.063908
# 2019-11-29  172.692339
# 2019-11-30  166.969685
# 2019-12-01  142.653830
# 2019-12-02  136.508808

# %%
dateprice.reset_index()
# Out:
#            date       price
# 0    2019-11-28  158.063908
# 1    2019-11-29  172.692339
# 2    2019-11-30  166.969685
# 3    2019-12-01  142.653830
# 4    2019-12-02  136.508808
# ..          ...         ...
# 360  2020-11-22  156.792298
# 361  2020-11-23  162.271610
# 362  2020-11-24  160.482589
# 363  2020-11-25  163.514543
# 364  2020-11-26  165.907415
#
# [365 rows x 2 columns]

# %%
x_axis = range(365)
y_axis = dateprice["price"]

plt.title('Average Price of Listings Over 1 Year')
plt.plot(x_axis, y_axis,linewidth=2, markersize=12)
plt.xlabel('Timepoint (Days)')
plt.ylabel('Average Daily Rental Price ($)')

plt.savefig('linechart')
plt.show()

# %%
datapts2 = dateprice.groupby('date').mean()['price']
forpanbar = pd.DataFrame(datapts2)
#newtry = forpanbar.reset_index()
#newtry

also = forpanbar.plot.bar(legend=False,rot=50)
also
plt.ylabel("Number of Data Points")
plt.title("Data Points Per Drug Treatment Regimen")
plt.savefig('barplot1')
